# %% [markdown]
# <a href="https://colab.research.google.com/github/kaushal4445/Learning-PANDAS/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {
    'Name' : ['A', 'B', 'C'],
    'Age'  :[11, 12, 14],
    'Deparment' : ['civil', 'cse', 'electrical'],
    'marks' : [23, 40, 36]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Name  Age   Deparment  marks
# 0    A   11       civil     23
# 1    B   12         cse     40
# 2    C   14  electrical     36

# %%
print("Head of the dataset : \n" , df.head())
print("Summary Satistics : \n" , df.describe())
print("\n Missing Values : \n", df.isnull().sum())
print(" \n Average marks by department \n ", df.groupby('Deparment')['marks'].mean())
# Out:
# Head of the dataset :
#    Name  Age   Deparment  marks
# 0    A   11       civil     23
# 1    B   12         cse     40
# 2    C   14  electrical     36
# Summary Satistics :
#               Age      marks
# count   3.000000   3.000000
# mean   12.333333  33.000000
# std     1.527525   8.888194
# min    11.000000  23.000000
# 25%    11.500000  29.500000
# 50%    12.000000  36.000000
# 75%    13.000000  38.000000
# max    14.000000  40.000000
#
#  Missing Values :
#  Name         0
# Age          0
# Deparment    0
# marks        0
# dtype: int64
#
#  Average marks by department
#   Deparment
# civil         23.0
# cse           40.0
# electrical    36.0
# Name: marks, dtype: float64

# %%
plt.figure(figsize=(5, 5))
plt.hist(df['marks'] , bins=5,  edgecolor='black')
plt.title('Distribution of Marks')
plt.xlabel('Marks')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
print(" \n Average marks by department \n ", df.groupby('Deparment')['marks'].mean())
plt.title('Distribution of Marks')
plt.xlabel('Marks')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-264/2342121543.py in <cell line: 0>()
# ----> 1 print(" \n Average marks by department \n ", df.groupby('Deparment')['marks'].mean())
#       2 plt.title('Distribution of Marks')
#       3 plt.xlabel('Marks')
#       4 plt.ylabel('Frequency')
#       5 plt.grid(True)
#
# NameError: name 'df' is not defined
